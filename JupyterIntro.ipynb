# %%
a = 1

# %%
b = 2

# %%
print('hello')

# %% [markdown]
# This is a title

# %% [markdown]
# # This is a title

# %% [markdown]
# # Below is a graph of st. line

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [1,2,3,4], 'o-')
plt.show()
